# %% [markdown]
# Exception

# %%
a = 'string'
b = 12
print(a + b) #TypeError: can only concatenate str (not "int") to str

# %%
a =
#SyntaxError: invalid syntax

# %%
print("Welcome")
x = divide(5, 2)  # NameError: name 'divide' is not defined
print(x)

def divide(a,b):
    return a/b

# %%
def divide ( a , b ):
    return a/b

x = divide(20,10)
print(x)

# %%
def divide ( a , b ):
    return a/b

x = divide(20,0)
print(x) # ZeroDivisionError: division by zero

# %%
def divide ( a , b ):
    try :
        return a/b
    except Exception as e:
        print("Something went wrong",e)

x = divide(20,10)
print(x)

# %%
def divide ( a , b ):
    try :
        return a/b
    except Exception as e:
        print("Something went wrong",e)

x = divide(20,0)
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print")


    except Exception as e:
        print(" Something went wrong",e)
    except ZeroDivisionError as zde:
        print(" wrong : ",zde)


x = divide(20,0)
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow


    except Exception as e:
        print(" Something went wrong",e)
    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why


x = divide(20,0)
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow


    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why


x = divide(20,0)
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except Exception as e:
        print(" Something went wrong",e)


x = divide(20,"a")
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except Exception as e:
        print(" Something went wrong",)
        return "Nothing"


x = divide(20,"a")
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except TypeError :
        print("Wrong data type")
    except Exception as e:
        print(" Something went wrong",)
        return "Nothing"


x = divide(20,"a")
print(x) # Absence of value
# program continued normally

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except TypeError :
        print("Wrong data type")
    except Exception as e:
        print(" Something went wrong",)
        return "Nothing"
    finally :
        print(" you existed successfully")
        return "finally" # it ran but with a warning
        # returned value changed run time


x = divide(20,"a")
print(x) # Absence of value
# program continued normally

# %%
try :
    print(10 + [1]

except Exception :
    print("Something went wrong")
except SyntaxError :
    print(' handled ')
print('prgram is alive')

# %%
try :
    print(10 + [1])

except Exception :
    print("Something went wrong")
else :
    print(" Addition succeed")
finally :
    print(' Resources released successfully !')
print('program is alive')

# %%
try :

    a = int(input("Enter a number: "))

except ValueError :
    print(" Wrong input")

# %%
# running

a = [1,2,3]
b = (1,2,3)
print(a*b) # TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
def mul(a,b):
     return a*b
a = [1,2,3]
b = (1,2,3)
print(mul(a,b)) # TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
b = (1,2,3)
print(b*2) # done , new tuple

# %%
b = (1,2,3)
print(b + 2 ) # TypeError: can only concatenate tuple (not "int") to tuple

# %%
a = [1,2,3]
b = (1,2,3)
print(a + b)

# %%
a = (1,2,3)
b = (1,2,3)
print(a + b)

# %%
a = {1,2,3,4}
print(a*2)

# %%
def divide(x,y):
    print(f'res is : {x/y}')
def m1(a,b):
    print(" method 1")
    divide(a,b)
def m2(g,h):
    print(" method 2")
    divide(g,h)

print("program start")
m2(12,2)

# %%
def divide(x,y):
    print(f'res is : {x/y}')
def m1(a,b):
    print(" method 1")
    divide(a,b)
def m2(g,h):
    print(" method 2")
    divide(g,h)

print("program start")
m2(12,'2')

# %%
def divide(x,y):
    print(" i am divide")
    print(f'res is : {x/y}')
def m1(a,b):
    print(" method 1")
    try :
        divide(a,b)
    except TypeError :
        print("Something went wrong")
def m2(g,h):
    print(" method 2")
    divide(g,h)

print("program start")
m2(12,'2')
# solved In Identify.
# Out:
# program start
#  method 2
#  i am divide
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 15
#      11     print(" method 2")
#      12     divide(g,h)
#      13
#      14 print("program start")
# ---> 15 m2(12,'2')
#      16 # solved In Identify.
#
# Cell In[24], line 12, in m2(g, h)
#      10 def m2(g,h):
#      11     print(" method 2")
# ---> 12     divide(g,h)
#
# Cell In[24], line 3, in divide(x, y)
#       1 def divide(x,y):
#       2     print(" i am divide")
# ----> 3     print(f'res is : {x/y}')
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
def divide(x,y):
    print(" i am divide")
    print(f'res is : {x/y}')
def m1(a,b):
    print(" method 1")
    divide(a,b)
def m2(g,h):
    print(" method 2")
    divide(g,h)

print("program start")
try :
    divide(a,b)
except TypeError :
    print("Something went wrong")
# m2(1)
# solved In 2,'2'Identify.
# Out:
# program start
#  i am divide
# Something went wrong

# %%
# %%sql
# show databases ;
# use memory ;
# show tables ;
# select * from pg_namespace ;
# Out:
#      oid nspname  nspowner  nspacl
# 0  20622    main         0    <NA>

# %%
try :
    print("program start")
# Out:
#   Cell In[38], line 2
#     print("program start")
#                           ^
# _IncompleteInputError: incomplete input

# %%
except :
print("Something went wrong")
# Out:
#   Cell In[40], line 1
#     except :
#     ^
# SyntaxError: invalid syntax

# %%
try :
    print("program start")
except Exception :
    print("Something went wrong")
# Out:
# program start

# %%
try :
    print("program start")
else :
    print("Something went wrong")
# Out:
#   Cell In[41], line 3
#     else :
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
try :
    print("program start")
finally:
    print("program end")
# Out:
# program start
# program end

# %%
try :
    try :
        print("program start")
# Out:
#   Cell In[43], line 3
#     print("program start")
#                           ^
# _IncompleteInputError: incomplete input

# %%
try :
    print("program start1")
    try :
        print("program start")
    except :
        print("Something went wrong1")
    finally:
        print("program end 1")
finally:
    print("program end")
# Out:
# program start1
# program start
# program end 1
# program end

# %%
try :
    print( 1 + a)
    try :
        print("program nested try")
    except Exception:
        print("Something went wrong")
    except TypeError :
        print(" Resolved")

except Exception:
        print("Something went wrong")

finally :
    print("program end")
# Out:
# Something went wrong
# program end
