# %%
# Type int
def show(name : str)  -> str :# data type dynamically typed
    print("Hello ,", name)
    return name

show("AT")
# Out:
# Hello , AT
# 'AT'

# %%
def show() : -> int
    print("jiii")

show()
# Out:
#   Cell In[11], line 1
#     def show() : -> int
#                  ^
# SyntaxError: invalid syntax

# %%
def show() -> int :
    print("jiii")

show()
# Out:
# jiii

# %%
def show() -> int :
    print("jiii")
    return None

show()
# Out:
# jiii

# %%
def show() -> int :
    print("jiii")
    return 0

show()
# Out:
# jiii
# 0

# %%
def show() -> int :
    print("jiii")
    return "string"

show()
# Out:
# jiii
# 'string'

# %%
def show() -> int :
    print("jiii")
    return None

x = show()
# Out:
# jiii
