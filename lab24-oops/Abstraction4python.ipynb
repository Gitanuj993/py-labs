# %% [markdown]
# Abstraction

# %% [markdown]
# downloading module abs

# %%
import abc

from oopm.t20 import Person


class A(abc.ABC) :
    def method1(self):
        print("method 1")
        pass


if __name__ == '__main__':
    a = A()
    a.method1()
# Out:
# method 1

# %%
from abc import ABC , abstractmethod

class A(ABC) :
    def method1(self):
        print("method 1")




class B(A) :
    def method1(self):
        print("method 1 of subclass")


if __name__ == '__main__':
    b = B()
    b.method1()
# Out:
# method 1 of subclass

# %%
from abc import ABC , abstractmethod

# why object of abstract class not
class A(ABC) :
    @abstractmethod
    def method1(self):
        print("method 1")


if __name__ == '__main__':
    pass

# %%
from abc import ABC , abstractmethod

# why object of abstract class not
class A(ABC) :
    @abstractmethod
    def method1(self):
        print("method 1")


if __name__ == '__main__':
    pass
    a = A()
    a.method1()

# TypeError: Can't instantiate abstract class A without an implementation for abstract method 'method1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 12
#       8
#       9
#      10 if __name__ == '__main__':
#      11     pass
# ---> 12     a = A()
#      13     a.method1()
#
# TypeError: Can't instantiate abstract class A without an implementation for abstract method 'method1'

# %%
from abc import ABC , abstractmethod

class Person(ABC) :
    @abstractmethod
    def work(self): # default behavior

        pass

class employee(Person) :
        def work(self):
            print(" I will do office work and i am in corporate, i get salary for the work")



class Student(Person) :

        def work(self):
            print(" I am a student and my work is to study and try new things , i do i didn't get payed for my studies but my work will componsate me later")

if __name__ == "__main__" :
        s1 = Student()
        s1.work()
        emp = employee()
        emp.work()
# Out:
#  I am a student and my work is to study and try new things , i do i didn't get payed for my studies but my work will componsate me later
#  I will do office work and i am in corporate, i get salary for the work

# %%
from abc import ABC , abstractmethod

class Person(ABC) :
    @abstractmethod
    def work(self): # default behavior

        pass

class employee(Person) :
        @abstractmethod
        def work(self):
            print(" I will do office work and i am in corporate, i get salary for the work")



class Student(Person) :

        def work(self):
            print(" I am a student and my work is to study and try new things , i do i didn't get payed for my studies but my work will componsate me later")

if __name__ == "__main__" :
        s1 = Student()
        s1.work()
        # emp = employee()
        # emp.work()
# Out:
#  I am a student and my work is to study and try new things , i do i didn't get payed for my studies but my work will componsate me later

# %%
from abc import ABC , abstractmethod

class Person(abc.ABC) :
    @abstractmethod
    def work(self): # default behavior
        pass





class employee(Person) :
        def work(self):
            print(" I will do office work and i am in corporate, i get salary for the work")



if __name__ == "__main__" :
    e1 = employee()
    e1.work()
# Out:
#  I will do office work and i am in corporate, i get salary for the work
