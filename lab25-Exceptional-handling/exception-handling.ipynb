# %% [markdown]
# Exception

# %%
a = 'string'
b = 12
print(a + b) #TypeError: can only concatenate str (not "int") to str

# %%
a =
#SyntaxError: invalid syntax

# %%
print("Welcome")
x = divide(5, 2)  # NameError: name 'divide' is not defined
print(x)

def divide(a,b):
    return a/b

# %%
def divide ( a , b ):
    return a/b

x = divide(20,10)
print(x)
# Out:
# 2.0

# %%
def divide ( a , b ):
    return a/b

x = divide(20,0)
print(x) # ZeroDivisionError: division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 def divide ( a , b ):
#       2     return a/b
#       3
# ----> 4 x = divide(20,0)
#       5 print(x) # ZeroDivisionError: division by zero
#
# Cell In[9], line 2, in divide(a, b)
#       1 def divide ( a , b ):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %%
def divide ( a , b ):
    try :
        return a/b
    except Exception as e:
        print("Something went wrong",e)

x = divide(20,10)
print(x)
# Out:
# 2.0

# %%
def divide ( a , b ):
    try :
        return a/b
    except Exception as e:
        print("Something went wrong",e)

x = divide(20,0)
print(x) # Absence of value
# program continued normally
# Out:
# Something went wrong division by zero
# None

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print")


    except Exception as e:
        print(" Something went wrong",e)
    except ZeroDivisionError as zde:
        print(" wrong : ",zde)


x = divide(20,0)
print(x) # Absence of value
# program continued normally
# Out:
#  check it
#  Something went wrong division by zero
# None

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow


    except Exception as e:
        print(" Something went wrong",e)
    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why


x = divide(20,0)
print(x) # Absence of value
# program continued normally
# Out:
#  check it
#  Something went wrong division by zero
# None

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow


    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why


x = divide(20,0)
print(x) # Absence of value
# program continued normally
# Out:
#  check it
# Nothing

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except Exception as e:
        print(" Something went wrong",e)


x = divide(20,"a")
print(x) # Absence of value
# program continued normally
# Out:
#  check it
#  Something went wrong unsupported operand type(s) for /: 'int' and 'str'
# None

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except Exception as e:
        print(" Something went wrong",)
        return "Nothing"


x = divide(20,"a")
print(x) # Absence of value
# program continued normally
# Out:
#  check it
#  Something went wrong
# Nothing

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except TypeError :
        print("Wrong data type")
    except Exception as e:
        print(" Something went wrong",)
        return "Nothing"


x = divide(20,"a")
print(x) # Absence of value
# program continued normally
# Out:
#  check it
# Wrong data type
# None

# %%
def divide ( a , b ):
    try :
        print(" check it")
        return a/b
        print(" its it print") # line after return will not run due to control flow



    except ZeroDivisionError as zde:
        #print(" wrong : ",zde)
        return "Nothing" # it doesn't run why
    except TypeError :
        print("Wrong data type")
    except Exception as e:
        print(" Something went wrong",)
        return "Nothing"
    finally :
        print(" you existed successfully")
        return "finally" # it ran but with a warning
        # returned value changed run time


x = divide(20,"a")
print(x) # Absence of value
# program continued normally
# Out:
#  check it
# Wrong data type
#  you existed successfully
# finally
# <>:19: SyntaxWarning: 'return' in a 'finally' block
# <>:19: SyntaxWarning: 'return' in a 'finally' block
# C:\Users\sdits\AppData\Local\Temp\ipykernel_7212\3825640913.py:19: SyntaxWarning: 'return' in a 'finally' block
#   return "finally"
